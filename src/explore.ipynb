# %% [markdown]
# # Explore here

# %%
# Your code here
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import recall_score, precision_score, f1_score, accuracy_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split, GridSearchCV

from sklearn.ensemble import RandomForestClassifier

from sklearn.tree import plot_tree

# %%
main_df = pd.read_csv('https://breathecode.herokuapp.com/asset/internal-link?id=421&path=diabetes.csv')

main_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
main_df.shape
# Out:
# (768, 9)

# %%
train_df, test_df = train_test_split(main_df, test_size = 0.2, random_state=4)

# %%
X_train = train_df.drop(columns=['Outcome'])
y_train = train_df['Outcome']

X_test = test_df.drop(columns=['Outcome'])
y_test = test_df['Outcome']

# %%
#this function makes predictions and prints out various evaluation metrics
def model_evaluator(X_matrix, y_target, model):
    preds = model.predict(X_matrix)
    
    print(f"Accuracy score: {round(accuracy_score(y_true = y_target, y_pred = preds),4)}")
    print(f"Precision score: {round(precision_score(y_true = y_target, y_pred = preds),4)}")
    print(f"Recall score: {round(recall_score(y_true = y_target, y_pred = preds),4)}")
    print(f"F1 score:{round(f1_score(y_true = y_target, y_pred = preds),4)}")
    print(f"Confusion matrix: \n{confusion_matrix(y_true = y_target, y_pred = preds)}")
    print(f"Classification report: \n{classification_report(y_true = y_target, y_pred = preds)}")

# %%
rf_model = RandomForestClassifier(random_state=101)

rf_model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 3
#       1 rf_model = RandomForestClassifier(random_state=101)
# ----> 3 rf_model.fit(X_train, y_train)
#
# File ~/.local/lib/python3.11/site-packages/sklearn/base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:486, in BaseForest.fit(self, X, y, sample_weight)
#     475 trees = [
#     476     self._make_estimator(append=False, random_state=random_state)
#     477     for i in range(n_more_estimators)
#     478 ]
#     480 # Parallel loop: we prefer the threading backend as the Cython code
#     481 # for fitting the trees is internally releasing the Python GIL
#     482 # making threading more efficient than multiprocessing in
#     483 # that case. However, for joblib 0.12+ we respect any
#     484 # parallel_backend contexts set at a higher level,
#     485 # since correctness does not rely on using threads.
# --> 486 trees = Parallel(
#     487     n_jobs=self.n_jobs,
#     488     verbose=self.verbose,
#     489     prefer="threads",
#     490 )(
#     491     delayed(_parallel_build_trees)(
#     492         t,
#     493         self.bootstrap,
#     494         X,
#     495         y,
#     496         sample_weight,
#     497         i,
#     498         len(trees),
#     499         verbose=self.verbose,
#     500         class_weight=self.class_weight,
#     501         n_samples_bootstrap=n_samples_bootstrap,
#     502         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     503     )
#     504     for i, t in enumerate(trees)
#     505 )
#     507 # Collect newly grown trees
#     508 self.estimators_.extend(trees)
#
# File ~/.local/lib/python3.11/site-packages/sklearn/utils/parallel.py:82, in Parallel.__call__(self, iterable)
#      73 warning_filters = warnings.filters
#      74 iterable_with_config_and_warning_filters = (
#      75     (
#      76         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     80     for delayed_func, args, kwargs in iterable
#      81 )
# ---> 82 return super().__call__(iterable_with_config_and_warning_filters)
#
# File ~/.local/lib/python3.11/site-packages/joblib/parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File ~/.local/lib/python3.11/site-packages/joblib/parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File ~/.local/lib/python3.11/site-packages/sklearn/utils/parallel.py:147, in _FuncWrapper.__call__(self, *args, **kwargs)
#     145 with config_context(**config), warnings.catch_warnings():
#     146     warnings.filters = warning_filters
# --> 147     return self.function(*args, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:188, in _parallel_build_trees(tree, bootstrap, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap, missing_values_in_feature_mask)
#     185     elif class_weight == "balanced_subsample":
#     186         curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
# --> 188     tree._fit(
#     189         X,
#     190         y,
#     191         sample_weight=curr_sample_weight,
#     192         check_input=False,
#     193         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     194     )
#     195 else:
#     196     tree._fit(
#     197         X,
#     198         y,
#    (...)    201         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     202     )
#
# File ~/.local/lib/python3.11/site-packages/sklearn/tree/_classes.py:239, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     231 def _fit(
#     232     self,
#     233     X,
#    (...)    237     missing_values_in_feature_mask=None,
#     238 ):
# --> 239     random_state = check_random_state(self.random_state)
#     241     if check_input:
#     242         # Need to validate separately here.
#     243         # We can't pass multi_output=True because that would allow y to be
#    (...)    246         # _compute_missing_values_in_feature_mask will check for finite values and
#     247         # compute the missing mask if the tree supports missing values
#     248         check_X_params = dict(
#     249             dtype=DTYPE, accept_sparse="csc", ensure_all_finite=False
#     250         )
#
# File ~/.local/lib/python3.11/site-packages/sklearn/utils/validation.py:1513, in check_random_state(seed)
#    1511     return np.random.mtrand._rand
#    1512 if isinstance(seed, numbers.Integral):
# -> 1513     return np.random.RandomState(seed)
#    1514 if isinstance(seed, np.random.RandomState):
#    1515     return seed
#
# KeyboardInterrupt:

# %%
model_evaluator(X_train, y_train, rf_model)
# Out:
# Accuracy score: 1.0
# Precision score: 1.0
# Recall score: 1.0
# F1 score:1.0
# Confusion matrix:
# [[402   0]
#  [  0 212]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       402
#            1       1.00      1.00      1.00       212
#
#     accuracy                           1.00       614
#    macro avg       1.00      1.00      1.00       614
# weighted avg       1.00      1.00      1.00       614

# %%
model_evaluator(X_test, y_test, rf_model)
# Out:
# Accuracy score: 0.7403
# Precision score: 0.6538
# Recall score: 0.6071
# F1 score:0.6296
# Confusion matrix:
# [[80 18]
#  [22 34]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.78      0.82      0.80        98
#            1       0.65      0.61      0.63        56
#
#     accuracy                           0.74       154
#    macro avg       0.72      0.71      0.71       154
# weighted avg       0.74      0.74      0.74       154

# %%
np.round(pd.DataFrame(rf_model.feature_importances_, rf_model.feature_names_in_)*100,2)
# Out:
#                               0
# Pregnancies                8.90
# Glucose                   26.53
# BloodPressure              8.61
# SkinThickness              7.02
# Insulin                    6.69
# BMI                       16.84
# DiabetesPedigreeFunction  10.82
# Age                       14.60

# %% [markdown]
# ### That wasn't great--our Random Forest model is overfitting on the training data. Let's tune the hyperparameters

# %%
hyperparameter_dict = {'n_estimators': [50, 100, 250],
                       'max_depth': [None, 5, 10],
                       'min_samples_split': [2, 4, 8],
                       'min_samples_leaf': [2, 4, 8]
                       }

# %%
gridsearch_model = GridSearchCV(estimator=RandomForestClassifier(),
                                param_grid=hyperparameter_dict,
                                scoring = 'accuracy',
                                verbose = 3,
                                cv=4)

# %%
gridsearch_model.fit(X_train, y_train)
# Out:
# Fitting 4 folds for each of 81 candidates, totalling 324 fits
# [CV 1/4] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.773 total time=   0.1s
# [CV 2/4] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.773 total time=   0.1s
# [CV 3/4] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.797 total time=   0.1s
# [CV 4/4] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.745 total time=   0.1s
# [CV 1/4] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.766 total time=   0.1s
# [CV 2/4] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.792 total time=   0.1s
# [CV 3/4] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.791 total time=   0.1s
# [CV 4/4] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.732 total time=   0.1s
# [CV 1/4] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=250;, score=0.792 total time=   0.3s
# [CV 2/4] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=250;, score=0.753 total time=   0.3s
# [CV 3/4] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=250;, score=0.784 total time=   0.3s
# [CV 4/4] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=250;, score=0.758 total time=   0.3s
# [CV 1/4] END max_depth=None, min_samples_leaf=2, min_samples_split=4, n_estimators=50;, score=0.792 total time=   0.1s
# [CV 2/4] END max_depth=None, min_samples_leaf=2, min_samples_split=4, n_estimators=50;, score=0.747 total time=   0.1s
# [CV 3/4] END max_depth=None, min_samples_leaf=2, min_samples_split=4, n_estimators=50;, score=0.797 total time=   0.1s
# [CV 4/4] END max_depth=None, min_samples_leaf=2, min_samples_split=4, n_estimators=50;, score=0.745 total time=   0.1s
# [CV 1/4] END max_depth=None, min_samples_leaf=2, min_samples_split=4, n_estimators=100;, score=0.779 total time=   0.1s
# [CV 2/4] END max_depth=None, min_samples_leaf=2, min_samples_split=4, n_estimators=100;, score=0.766 total time=   0.1s
# [CV 3/4] END max_depth=None, min_samples_leaf=2, min_samples_split=4, n_estimators=100;, score=0.797 total time=   0.1s
# [CV 4/4] END max_depth=None, min_samples_leaf=2, min_samples_split=4, n_estimators=100;, score=0.752 total time=   0.1s
# [CV 1/4] END max_depth=None, min_samples_leaf=2, min_samples_split=4, n_estimators=250;, score=0.779 total time=   0.4s
# [CV 2/4] END max_depth=None, min_samples_leaf=2, min_samples_split=4, n_estimators=250;, score=0.773 total time=   0.4s
# [CV 3/4] END max_depth=None, min_samples_leaf=2, min_samples_split=4, n_estimators=250;, score=0.784 total time=   0.3s
# [CV 4/4] END max_depth=None, min_samples_leaf=2, min_samples_split=4, n_estimators=250;, score=0.758 total time=   0.3s
# [CV 1/4] END max_depth=None, min_samples_leaf=2, min_samples_split=8, n_estimators=50;, score=0.786 total time=   0.1s
# [CV 2/4] END max_depth=None, min_samples_leaf=2, min_samples_split=8, n_estimators=50;, score=0.753 total time=   0.1s
# [CV 3/4] END max_depth=None, min_samples_leaf=2, min_samples_split=8, n_estimators=50;, score=0.778 total time=   0.1s
# [CV 4/4] END max_depth=None, min_samples_leaf=2, min_samples_split=8, n_estimators=50;, score=0.771 total time=   0.1s
# [CV 1/4] END max_depth=None, min_samples_leaf=2, min_samples_split=8, n_estimators=100;, score=0.786 total time=   0.1s
# [CV 2/4] END max_depth=None, min_samples_leaf=2, min_samples_split=8, n_estimators=100;, score=0.740 total time=   0.1s
# [CV 3/4] END max_depth=None, min_samples_leaf=2, min_samples_split=8, n_estimators=100;, score=0.778 total time=   0.1s
# [CV 4/4] END max_depth=None, min_samples_leaf=2, min_samples_split=8, n_estimators=100;, score=0.732 total time=   0.1s
# [CV 1/4] END max_depth=None, min_samples_leaf=2, min_samples_split=8, n_estimators=250;, score=0.805 total time=   0.3s
# [CV 2/4] END max_depth=None, min_samples_leaf=2, min_samples_split=8, n_estimators=250;, score=0.760 total time=   0.3s
# [CV 3/4] END max_depth=None, min_samples_leaf=2, min_samples_split=8, n_estimators=250;, score=0.765 total time=   0.3s
# [CV 4/4] END max_depth=None, min_samples_leaf=2, min_samples_split=8, n_estimators=250;, score=0.765 total time=   0.3s
# [CV 1/4] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.818 total time=   0.1s
# [CV 2/4] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.773 total time=   0.1s
# [CV 3/4] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.765 total time=   0.1s
# [CV 4/4] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.758 total time=   0.1s
# [CV 1/4] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.792 total time=   0.2s
# [CV 2/4] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.792 total time=   0.2s
# [CV 3/4] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.784 total time=   0.1s
# [CV 4/4] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.752 total time=   0.1s
# [CV 1/4] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=250;, score=0.805 total time=   0.3s
# [CV 2/4] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=250;, score=0.760 total time=   0.3s
# [CV 3/4] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=250;, score=0.784 total time=   0.3s
# [CV 4/4] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=250;, score=0.752 total time=   0.3s
# [CV 1/4] END max_depth=None, min_samples_leaf=4, min_samples_split=4, n_estimators=50;, score=0.792 total time=   0.1s
# [CV 2/4] END max_depth=None, min_samples_leaf=4, min_samples_split=4, n_estimators=50;, score=0.779 total time=   0.1s
# [CV 3/4] END max_depth=None, min_samples_leaf=4, min_samples_split=4, n_estimators=50;, score=0.771 total time=   0.1s
# [CV 4/4] END max_depth=None, min_samples_leaf=4, min_samples_split=4, n_estimators=50;, score=0.752 total time=   0.1s
# [CV 1/4] END max_depth=None, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.812 total time=   0.1s
# [CV 2/4] END max_depth=None, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.740 total time=   0.1s
# [CV 3/4] END max_depth=None, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.784 total time=   0.1s
# [CV 4/4] END max_depth=None, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.778 total time=   0.1s
# [CV 1/4] END max_depth=None, min_samples_leaf=4, min_samples_split=4, n_estimators=250;, score=0.805 total time=   0.3s
# [CV 2/4] END max_depth=None, min_samples_leaf=4, min_samples_split=4, n_estimators=250;, score=0.766 total time=   0.3s
# [CV 3/4] END max_depth=None, min_samples_leaf=4, min_samples_split=4, n_estimators=250;, score=0.784 total time=   0.4s
# [CV 4/4] END max_depth=None, min_samples_leaf=4, min_samples_split=4, n_estimators=250;, score=0.739 total time=   0.3s
# [CV 1/4] END max_depth=None, min_samples_leaf=4, min_samples_split=8, n_estimators=50;, score=0.799 total time=   0.1s
# [CV 2/4] END max_depth=None, min_samples_leaf=4, min_samples_split=8, n_estimators=50;, score=0.766 total time=   0.1s
# [CV 3/4] END max_depth=None, min_samples_leaf=4, min_samples_split=8, n_estimators=50;, score=0.791 total time=   0.1s
# [CV 4/4] END max_depth=None, min_samples_leaf=4, min_samples_split=8, n_estimators=50;, score=0.732 total time=   0.1s
# [CV 1/4] END max_depth=None, min_samples_leaf=4, min_samples_split=8, n_estimators=100;, score=0.799 total time=   0.1s
# [CV 2/4] END max_depth=None, min_samples_leaf=4, min_samples_split=8, n_estimators=100;, score=0.747 total time=   0.1s
# [CV 3/4] END max_depth=None, min_samples_leaf=4, min_samples_split=8, n_estimators=100;, score=0.797 total time=   0.1s
# [CV 4/4] END max_depth=None, min_samples_leaf=4, min_samples_split=8, n_estimators=100;, score=0.765 total time=   0.1s
# [CV 1/4] END max_depth=None, min_samples_leaf=4, min_samples_split=8, n_estimators=250;, score=0.825 total time=   0.3s
# [CV 2/4] END max_depth=None, min_samples_leaf=4, min_samples_split=8, n_estimators=250;, score=0.773 total time=   0.3s
# [CV 3/4] END max_depth=None, min_samples_leaf=4, min_samples_split=8, n_estimators=250;, score=0.791 total time=   0.3s
# [CV 4/4] END max_depth=None, min_samples_leaf=4, min_samples_split=8, n_estimators=250;, score=0.745 total time=   0.4s
# [CV 1/4] END max_depth=None, min_samples_leaf=8, min_samples_split=2, n_estimators=50;, score=0.753 total time=   0.1s
# [CV 2/4] END max_depth=None, min_samples_leaf=8, min_samples_split=2, n_estimators=50;, score=0.773 total time=   0.1s
# [CV 3/4] END max_depth=None, min_samples_leaf=8, min_samples_split=2, n_estimators=50;, score=0.765 total time=   0.1s
# [CV 4/4] END max_depth=None, min_samples_leaf=8, min_samples_split=2, n_estimators=50;, score=0.732 total time=   0.1s
# [CV 1/4] END max_depth=None, min_samples_leaf=8, min_samples_split=2, n_estimators=100;, score=0.805 total time=   0.1s
# [CV 2/4] END max_depth=None, min_samples_leaf=8, min_samples_split=2, n_estimators=100;, score=0.773 total time=   0.1s
# [CV 3/4] END max_depth=None, min_samples_leaf=8, min_samples_split=2, n_estimators=100;, score=0.771 total time=   0.1s
# [CV 4/4] END max_depth=None, min_samples_leaf=8, min_samples_split=2, n_estimators=100;, score=0.725 total time=   0.1s
# [CV 1/4] END max_depth=None, min_samples_leaf=8, min_samples_split=2, n_estimators=250;, score=0.818 total time=   0.3s
# [CV 2/4] END max_depth=None, min_samples_leaf=8, min_samples_split=2, n_estimators=250;, score=0.766 total time=   0.3s
# [CV 3/4] END max_depth=None, min_samples_leaf=8, min_samples_split=2, n_estimators=250;, score=0.784 total time=   0.3s
# [CV 4/4] END max_depth=None, min_samples_leaf=8, min_samples_split=2, n_estimators=250;, score=0.745 total time=   0.3s
# [CV 1/4] END max_depth=None, min_samples_leaf=8, min_samples_split=4, n_estimators=50;, score=0.773 total time=   0.1s
# [CV 2/4] END max_depth=None, min_samples_leaf=8, min_samples_split=4, n_estimators=50;, score=0.760 total time=   0.1s
# [CV 3/4] END max_depth=None, min_samples_leaf=8, min_samples_split=4, n_estimators=50;, score=0.791 total time=   0.1s
# [CV 4/4] END max_depth=None, min_samples_leaf=8, min_samples_split=4, n_estimators=50;, score=0.758 total time=   0.1s
# [CV 1/4] END max_depth=None, min_samples_leaf=8, min_samples_split=4, n_estimators=100;, score=0.812 total time=   0.1s
# [CV 2/4] END max_depth=None, min_samples_leaf=8, min_samples_split=4, n_estimators=100;, score=0.773 total time=   0.1s
# [CV 3/4] END max_depth=None, min_samples_leaf=8, min_samples_split=4, n_estimators=100;, score=0.771 total time=   0.1s
# [CV 4/4] END max_depth=None, min_samples_leaf=8, min_samples_split=4, n_estimators=100;, score=0.758 total time=   0.1s
# [CV 1/4] END max_depth=None, min_samples_leaf=8, min_samples_split=4, n_estimators=250;, score=0.805 total time=   0.4s
# [CV 2/4] END max_depth=None, min_samples_leaf=8, min_samples_split=4, n_estimators=250;, score=0.773 total time=   0.3s
# [CV 3/4] END max_depth=None, min_samples_leaf=8, min_samples_split=4, n_estimators=250;, score=0.771 total time=   0.3s
# [CV 4/4] END max_depth=None, min_samples_leaf=8, min_samples_split=4, n_estimators=250;, score=0.745 total time=   0.3s
# [CV 1/4] END max_depth=None, min_samples_leaf=8, min_samples_split=8, n_estimators=50;, score=0.799 total time=   0.1s
# [CV 2/4] END max_depth=None, min_samples_leaf=8, min_samples_split=8, n_estimators=50;, score=0.740 total time=   0.1s
# [CV 3/4] END max_depth=None, min_samples_leaf=8, min_samples_split=8, n_estimators=50;, score=0.778 total time=   0.1s
# [CV 4/4] END max_depth=None, min_samples_leaf=8, min_samples_split=8, n_estimators=50;, score=0.725 total time=   0.1s
# [CV 1/4] END max_depth=None, min_samples_leaf=8, min_samples_split=8, n_estimators=100;, score=0.812 total time=   0.1s
# [CV 2/4] END max_depth=None, min_samples_leaf=8, min_samples_split=8, n_estimators=100;, score=0.760 total time=   0.1s
# [CV 3/4] END max_depth=None, min_samples_leaf=8, min_samples_split=8, n_estimators=100;, score=0.765 total time=   0.1s
# [CV 4/4] END max_depth=None, min_samples_leaf=8, min_samples_split=8, n_estimators=100;, score=0.732 total time=   0.1s
# [CV 1/4] END max_depth=None, min_samples_leaf=8, min_samples_split=8, n_estimators=250;, score=0.818 total time=   0.3s
# [CV 2/4] END max_depth=None, min_samples_leaf=8, min_samples_split=8, n_estimators=250;, score=0.760 total time=   0.3s
# [CV 3/4] END max_depth=None, min_samples_leaf=8, min_samples_split=8, n_estimators=250;, score=0.784 total time=   0.3s
# [CV 4/4] END max_depth=None, min_samples_leaf=8, min_samples_split=8, n_estimators=250;, score=0.725 total time=   0.3s
# [CV 1/4] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.779 total time=   0.1s
# [CV 2/4] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.760 total time=   0.1s
# [CV 3/4] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.771 total time=   0.1s
# [CV 4/4] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.732 total time=   0.1s
# [CV 1/4] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.805 total time=   0.1s
# [CV 2/4] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.792 total time=   0.1s
# [CV 3/4] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.784 total time=   0.1s
# [CV 4/4] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.739 total time=   0.1s
# [CV 1/4] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=250;, score=0.792 total time=   0.3s
# [CV 2/4] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=250;, score=0.786 total time=   0.3s
# [CV 3/4] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=250;, score=0.771 total time=   0.3s
# [CV 4/4] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=250;, score=0.732 total time=   0.3s
# [CV 1/4] END max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=50;, score=0.812 total time=   0.1s
# [CV 2/4] END max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=50;, score=0.773 total time=   0.1s
# [CV 3/4] END max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=50;, score=0.758 total time=   0.1s
# [CV 4/4] END max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=50;, score=0.725 total time=   0.1s
# [CV 1/4] END max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=100;, score=0.799 total time=   0.1s
# [CV 2/4] END max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=100;, score=0.766 total time=   0.1s
# [CV 3/4] END max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=100;, score=0.765 total time=   0.2s
# [CV 4/4] END max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=100;, score=0.758 total time=   0.1s
# [CV 1/4] END max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=250;, score=0.812 total time=   0.3s
# [CV 2/4] END max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=250;, score=0.786 total time=   0.3s
# [CV 3/4] END max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=250;, score=0.771 total time=   0.3s
# [CV 4/4] END max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=250;, score=0.732 total time=   0.3s
# [CV 1/4] END max_depth=5, min_samples_leaf=2, min_samples_split=8, n_estimators=50;, score=0.786 total time=   0.1s
# [CV 2/4] END max_depth=5, min_samples_leaf=2, min_samples_split=8, n_estimators=50;, score=0.779 total time=   0.1s
# [CV 3/4] END max_depth=5, min_samples_leaf=2, min_samples_split=8, n_estimators=50;, score=0.758 total time=   0.1s
# [CV 4/4] END max_depth=5, min_samples_leaf=2, min_samples_split=8, n_estimators=50;, score=0.758 total time=   0.1s
# [CV 1/4] END max_depth=5, min_samples_leaf=2, min_samples_split=8, n_estimators=100;, score=0.786 total time=   0.1s
# [CV 2/4] END max_depth=5, min_samples_leaf=2, min_samples_split=8, n_estimators=100;, score=0.773 total time=   0.1s
# [CV 3/4] END max_depth=5, min_samples_leaf=2, min_samples_split=8, n_estimators=100;, score=0.758 total time=   0.1s
# [CV 4/4] END max_depth=5, min_samples_leaf=2, min_samples_split=8, n_estimators=100;, score=0.752 total time=   0.1s
# [CV 1/4] END max_depth=5, min_samples_leaf=2, min_samples_split=8, n_estimators=250;, score=0.792 total time=   0.3s
# [CV 2/4] END max_depth=5, min_samples_leaf=2, min_samples_split=8, n_estimators=250;, score=0.779 total time=   0.3s
# [CV 3/4] END max_depth=5, min_samples_leaf=2, min_samples_split=8, n_estimators=250;, score=0.752 total time=   0.3s
# [CV 4/4] END max_depth=5, min_samples_leaf=2, min_samples_split=8, n_estimators=250;, score=0.758 total time=   0.3s
# [CV 1/4] END max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.792 total time=   0.1s
# [CV 2/4] END max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.740 total time=   0.1s
# [CV 3/4] END max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.778 total time=   0.1s
# [CV 4/4] END max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.758 total time=   0.1s
# [CV 1/4] END max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.799 total time=   0.1s
# [CV 2/4] END max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.779 total time=   0.1s
# [CV 3/4] END max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.758 total time=   0.1s
# [CV 4/4] END max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.758 total time=   0.1s
# [CV 1/4] END max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=250;, score=0.799 total time=   0.3s
# [CV 2/4] END max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=250;, score=0.779 total time=   0.3s
# [CV 3/4] END max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=250;, score=0.778 total time=   0.3s
# [CV 4/4] END max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=250;, score=0.745 total time=   0.3s
# [CV 1/4] END max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=50;, score=0.799 total time=   0.1s
# [CV 2/4] END max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=50;, score=0.766 total time=   0.1s
# [CV 3/4] END max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=50;, score=0.758 total time=   0.1s
# [CV 4/4] END max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=50;, score=0.725 total time=   0.1s
# [CV 1/4] END max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.792 total time=   0.1s
# [CV 2/4] END max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.786 total time=   0.1s
# [CV 3/4] END max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.771 total time=   0.1s
# [CV 4/4] END max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.725 total time=   0.1s
# [CV 1/4] END max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=250;, score=0.805 total time=   0.3s
# [CV 2/4] END max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=250;, score=0.773 total time=   0.3s
# [CV 3/4] END max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=250;, score=0.771 total time=   0.3s
# [CV 4/4] END max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=250;, score=0.739 total time=   0.3s
# [CV 1/4] END max_depth=5, min_samples_leaf=4, min_samples_split=8, n_estimators=50;, score=0.779 total time=   0.1s
# [CV 2/4] END max_depth=5, min_samples_leaf=4, min_samples_split=8, n_estimators=50;, score=0.753 total time=   0.1s
# [CV 3/4] END max_depth=5, min_samples_leaf=4, min_samples_split=8, n_estimators=50;, score=0.758 total time=   0.1s
# [CV 4/4] END max_depth=5, min_samples_leaf=4, min_samples_split=8, n_estimators=50;, score=0.745 total time=   0.1s
# [CV 1/4] END max_depth=5, min_samples_leaf=4, min_samples_split=8, n_estimators=100;, score=0.805 total time=   0.1s
# [CV 2/4] END max_depth=5, min_samples_leaf=4, min_samples_split=8, n_estimators=100;, score=0.773 total time=   0.1s
# [CV 3/4] END max_depth=5, min_samples_leaf=4, min_samples_split=8, n_estimators=100;, score=0.784 total time=   0.1s
# [CV 4/4] END max_depth=5, min_samples_leaf=4, min_samples_split=8, n_estimators=100;, score=0.745 total time=   0.2s
# [CV 1/4] END max_depth=5, min_samples_leaf=4, min_samples_split=8, n_estimators=250;, score=0.786 total time=   0.3s
# [CV 2/4] END max_depth=5, min_samples_leaf=4, min_samples_split=8, n_estimators=250;, score=0.773 total time=   0.3s
# [CV 3/4] END max_depth=5, min_samples_leaf=4, min_samples_split=8, n_estimators=250;, score=0.778 total time=   0.3s
# [CV 4/4] END max_depth=5, min_samples_leaf=4, min_samples_split=8, n_estimators=250;, score=0.752 total time=   0.3s
# [CV 1/4] END max_depth=5, min_samples_leaf=8, min_samples_split=2, n_estimators=50;, score=0.779 total time=   0.1s
# [CV 2/4] END max_depth=5, min_samples_leaf=8, min_samples_split=2, n_estimators=50;, score=0.760 total time=   0.1s
# [CV 3/4] END max_depth=5, min_samples_leaf=8, min_samples_split=2, n_estimators=50;, score=0.771 total time=   0.1s
# [CV 4/4] END max_depth=5, min_samples_leaf=8, min_samples_split=2, n_estimators=50;, score=0.745 total time=   0.1s
# [CV 1/4] END max_depth=5, min_samples_leaf=8, min_samples_split=2, n_estimators=100;, score=0.805 total time=   0.1s
# [CV 2/4] END max_depth=5, min_samples_leaf=8, min_samples_split=2, n_estimators=100;, score=0.779 total time=   0.1s
# [CV 3/4] END max_depth=5, min_samples_leaf=8, min_samples_split=2, n_estimators=100;, score=0.758 total time=   0.1s
# [CV 4/4] END max_depth=5, min_samples_leaf=8, min_samples_split=2, n_estimators=100;, score=0.732 total time=   0.1s
# [CV 1/4] END max_depth=5, min_samples_leaf=8, min_samples_split=2, n_estimators=250;, score=0.792 total time=   0.3s
# [CV 2/4] END max_depth=5, min_samples_leaf=8, min_samples_split=2, n_estimators=250;, score=0.773 total time=   0.3s
# [CV 3/4] END max_depth=5, min_samples_leaf=8, min_samples_split=2, n_estimators=250;, score=0.778 total time=   0.3s
# [CV 4/4] END max_depth=5, min_samples_leaf=8, min_samples_split=2, n_estimators=250;, score=0.739 total time=   0.3s
# [CV 1/4] END max_depth=5, min_samples_leaf=8, min_samples_split=4, n_estimators=50;, score=0.792 total time=   0.1s
# [CV 2/4] END max_depth=5, min_samples_leaf=8, min_samples_split=4, n_estimators=50;, score=0.773 total time=   0.1s
# [CV 3/4] END max_depth=5, min_samples_leaf=8, min_samples_split=4, n_estimators=50;, score=0.765 total time=   0.1s
# [CV 4/4] END max_depth=5, min_samples_leaf=8, min_samples_split=4, n_estimators=50;, score=0.732 total time=   0.1s
# [CV 1/4] END max_depth=5, min_samples_leaf=8, min_samples_split=4, n_estimators=100;, score=0.812 total time=   0.1s
# [CV 2/4] END max_depth=5, min_samples_leaf=8, min_samples_split=4, n_estimators=100;, score=0.779 total time=   0.1s
# [CV 3/4] END max_depth=5, min_samples_leaf=8, min_samples_split=4, n_estimators=100;, score=0.765 total time=   0.1s
# [CV 4/4] END max_depth=5, min_samples_leaf=8, min_samples_split=4, n_estimators=100;, score=0.752 total time=   0.1s
# [CV 1/4] END max_depth=5, min_samples_leaf=8, min_samples_split=4, n_estimators=250;, score=0.812 total time=   0.3s
# [CV 2/4] END max_depth=5, min_samples_leaf=8, min_samples_split=4, n_estimators=250;, score=0.773 total time=   0.3s
# [CV 3/4] END max_depth=5, min_samples_leaf=8, min_samples_split=4, n_estimators=250;, score=0.752 total time=   0.3s
# [CV 4/4] END max_depth=5, min_samples_leaf=8, min_samples_split=4, n_estimators=250;, score=0.752 total time=   0.3s
# [CV 1/4] END max_depth=5, min_samples_leaf=8, min_samples_split=8, n_estimators=50;, score=0.792 total time=   0.1s
# [CV 2/4] END max_depth=5, min_samples_leaf=8, min_samples_split=8, n_estimators=50;, score=0.779 total time=   0.1s
# [CV 3/4] END max_depth=5, min_samples_leaf=8, min_samples_split=8, n_estimators=50;, score=0.765 total time=   0.1s
# [CV 4/4] END max_depth=5, min_samples_leaf=8, min_samples_split=8, n_estimators=50;, score=0.719 total time=   0.1s
# [CV 1/4] END max_depth=5, min_samples_leaf=8, min_samples_split=8, n_estimators=100;, score=0.805 total time=   0.1s
# [CV 2/4] END max_depth=5, min_samples_leaf=8, min_samples_split=8, n_estimators=100;, score=0.786 total time=   0.1s
# [CV 3/4] END max_depth=5, min_samples_leaf=8, min_samples_split=8, n_estimators=100;, score=0.758 total time=   0.1s
# [CV 4/4] END max_depth=5, min_samples_leaf=8, min_samples_split=8, n_estimators=100;, score=0.745 total time=   0.1s
# [CV 1/4] END max_depth=5, min_samples_leaf=8, min_samples_split=8, n_estimators=250;, score=0.812 total time=   0.3s
# [CV 2/4] END max_depth=5, min_samples_leaf=8, min_samples_split=8, n_estimators=250;, score=0.766 total time=   0.3s
# [CV 3/4] END max_depth=5, min_samples_leaf=8, min_samples_split=8, n_estimators=250;, score=0.758 total time=   0.3s
# [CV 4/4] END max_depth=5, min_samples_leaf=8, min_samples_split=8, n_estimators=250;, score=0.745 total time=   0.3s
# [CV 1/4] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.792 total time=   0.1s
# [CV 2/4] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.760 total time=   0.1s
# [CV 3/4] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.765 total time=   0.1s
# [CV 4/4] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.706 total time=   0.1s
# [CV 1/4] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.812 total time=   0.1s
# [CV 2/4] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.747 total time=   0.1s
# [CV 3/4] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.771 total time=   0.1s
# [CV 4/4] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.752 total time=   0.1s
# [CV 1/4] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=250;, score=0.792 total time=   0.3s
# [CV 2/4] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=250;, score=0.760 total time=   0.3s
# [CV 3/4] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=250;, score=0.765 total time=   0.3s
# [CV 4/4] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=250;, score=0.745 total time=   0.4s
# [CV 1/4] END max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=50;, score=0.766 total time=   0.1s
# [CV 2/4] END max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=50;, score=0.753 total time=   0.1s
# [CV 3/4] END max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=50;, score=0.752 total time=   0.1s
# [CV 4/4] END max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=50;, score=0.739 total time=   0.1s
# [CV 1/4] END max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=100;, score=0.779 total time=   0.1s
# [CV 2/4] END max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=100;, score=0.792 total time=   0.1s
# [CV 3/4] END max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=100;, score=0.778 total time=   0.1s
# [CV 4/4] END max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=100;, score=0.758 total time=   0.1s
# [CV 1/4] END max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=250;, score=0.792 total time=   0.3s
# [CV 2/4] END max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=250;, score=0.766 total time=   0.3s
# [CV 3/4] END max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=250;, score=0.791 total time=   0.3s
# [CV 4/4] END max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=250;, score=0.725 total time=   0.3s
# [CV 1/4] END max_depth=10, min_samples_leaf=2, min_samples_split=8, n_estimators=50;, score=0.805 total time=   0.1s
# [CV 2/4] END max_depth=10, min_samples_leaf=2, min_samples_split=8, n_estimators=50;, score=0.773 total time=   0.1s
# [CV 3/4] END max_depth=10, min_samples_leaf=2, min_samples_split=8, n_estimators=50;, score=0.778 total time=   0.1s
# [CV 4/4] END max_depth=10, min_samples_leaf=2, min_samples_split=8, n_estimators=50;, score=0.758 total time=   0.1s
# [CV 1/4] END max_depth=10, min_samples_leaf=2, min_samples_split=8, n_estimators=100;, score=0.799 total time=   0.1s
# [CV 2/4] END max_depth=10, min_samples_leaf=2, min_samples_split=8, n_estimators=100;, score=0.760 total time=   0.1s
# [CV 3/4] END max_depth=10, min_samples_leaf=2, min_samples_split=8, n_estimators=100;, score=0.778 total time=   0.1s
# [CV 4/4] END max_depth=10, min_samples_leaf=2, min_samples_split=8, n_estimators=100;, score=0.745 total time=   0.1s
# [CV 1/4] END max_depth=10, min_samples_leaf=2, min_samples_split=8, n_estimators=250;, score=0.786 total time=   0.3s
# [CV 2/4] END max_depth=10, min_samples_leaf=2, min_samples_split=8, n_estimators=250;, score=0.779 total time=   0.3s
# [CV 3/4] END max_depth=10, min_samples_leaf=2, min_samples_split=8, n_estimators=250;, score=0.778 total time=   0.3s
# [CV 4/4] END max_depth=10, min_samples_leaf=2, min_samples_split=8, n_estimators=250;, score=0.739 total time=   0.3s
# [CV 1/4] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.792 total time=   0.1s
# [CV 2/4] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.747 total time=   0.1s
# [CV 3/4] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.771 total time=   0.1s
# [CV 4/4] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.739 total time=   0.1s
# [CV 1/4] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.799 total time=   0.1s
# [CV 2/4] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.779 total time=   0.1s
# [CV 3/4] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.784 total time=   0.1s
# [CV 4/4] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.752 total time=   0.1s
# [CV 1/4] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=250;, score=0.805 total time=   0.4s
# [CV 2/4] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=250;, score=0.766 total time=   0.3s
# [CV 3/4] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=250;, score=0.791 total time=   0.3s
# [CV 4/4] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=250;, score=0.758 total time=   0.3s
# [CV 1/4] END max_depth=10, min_samples_leaf=4, min_samples_split=4, n_estimators=50;, score=0.786 total time=   0.1s
# [CV 2/4] END max_depth=10, min_samples_leaf=4, min_samples_split=4, n_estimators=50;, score=0.760 total time=   0.1s
# [CV 3/4] END max_depth=10, min_samples_leaf=4, min_samples_split=4, n_estimators=50;, score=0.778 total time=   0.1s
# [CV 4/4] END max_depth=10, min_samples_leaf=4, min_samples_split=4, n_estimators=50;, score=0.765 total time=   0.1s
# [CV 1/4] END max_depth=10, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.779 total time=   0.1s
# [CV 2/4] END max_depth=10, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.760 total time=   0.1s
# [CV 3/4] END max_depth=10, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.784 total time=   0.1s
# [CV 4/4] END max_depth=10, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.745 total time=   0.1s
# [CV 1/4] END max_depth=10, min_samples_leaf=4, min_samples_split=4, n_estimators=250;, score=0.792 total time=   0.3s
# [CV 2/4] END max_depth=10, min_samples_leaf=4, min_samples_split=4, n_estimators=250;, score=0.760 total time=   0.3s
# [CV 3/4] END max_depth=10, min_samples_leaf=4, min_samples_split=4, n_estimators=250;, score=0.784 total time=   0.3s
# [CV 4/4] END max_depth=10, min_samples_leaf=4, min_samples_split=4, n_estimators=250;, score=0.739 total time=   0.3s
# [CV 1/4] END max_depth=10, min_samples_leaf=4, min_samples_split=8, n_estimators=50;, score=0.786 total time=   0.1s
# [CV 2/4] END max_depth=10, min_samples_leaf=4, min_samples_split=8, n_estimators=50;, score=0.773 total time=   0.1s
# [CV 3/4] END max_depth=10, min_samples_leaf=4, min_samples_split=8, n_estimators=50;, score=0.797 total time=   0.1s
# [CV 4/4] END max_depth=10, min_samples_leaf=4, min_samples_split=8, n_estimators=50;, score=0.745 total time=   0.1s
# [CV 1/4] END max_depth=10, min_samples_leaf=4, min_samples_split=8, n_estimators=100;, score=0.812 total time=   0.1s
# [CV 2/4] END max_depth=10, min_samples_leaf=4, min_samples_split=8, n_estimators=100;, score=0.766 total time=   0.1s
# [CV 3/4] END max_depth=10, min_samples_leaf=4, min_samples_split=8, n_estimators=100;, score=0.778 total time=   0.1s
# [CV 4/4] END max_depth=10, min_samples_leaf=4, min_samples_split=8, n_estimators=100;, score=0.745 total time=   0.1s
# [CV 1/4] END max_depth=10, min_samples_leaf=4, min_samples_split=8, n_estimators=250;, score=0.792 total time=   0.3s
# [CV 2/4] END max_depth=10, min_samples_leaf=4, min_samples_split=8, n_estimators=250;, score=0.753 total time=   0.3s
# [CV 3/4] END max_depth=10, min_samples_leaf=4, min_samples_split=8, n_estimators=250;, score=0.784 total time=   0.3s
# [CV 4/4] END max_depth=10, min_samples_leaf=4, min_samples_split=8, n_estimators=250;, score=0.765 total time=   0.3s
# [CV 1/4] END max_depth=10, min_samples_leaf=8, min_samples_split=2, n_estimators=50;, score=0.831 total time=   0.1s
# [CV 2/4] END max_depth=10, min_samples_leaf=8, min_samples_split=2, n_estimators=50;, score=0.773 total time=   0.1s
# [CV 3/4] END max_depth=10, min_samples_leaf=8, min_samples_split=2, n_estimators=50;, score=0.778 total time=   0.1s
# [CV 4/4] END max_depth=10, min_samples_leaf=8, min_samples_split=2, n_estimators=50;, score=0.745 total time=   0.1s
# [CV 1/4] END max_depth=10, min_samples_leaf=8, min_samples_split=2, n_estimators=100;, score=0.805 total time=   0.2s
# [CV 2/4] END max_depth=10, min_samples_leaf=8, min_samples_split=2, n_estimators=100;, score=0.760 total time=   0.1s
# [CV 3/4] END max_depth=10, min_samples_leaf=8, min_samples_split=2, n_estimators=100;, score=0.778 total time=   0.1s
# [CV 4/4] END max_depth=10, min_samples_leaf=8, min_samples_split=2, n_estimators=100;, score=0.745 total time=   0.1s
# [CV 1/4] END max_depth=10, min_samples_leaf=8, min_samples_split=2, n_estimators=250;, score=0.792 total time=   0.3s
# [CV 2/4] END max_depth=10, min_samples_leaf=8, min_samples_split=2, n_estimators=250;, score=0.773 total time=   0.3s
# [CV 3/4] END max_depth=10, min_samples_leaf=8, min_samples_split=2, n_estimators=250;, score=0.791 total time=   0.3s
# [CV 4/4] END max_depth=10, min_samples_leaf=8, min_samples_split=2, n_estimators=250;, score=0.739 total time=   0.3s
# [CV 1/4] END max_depth=10, min_samples_leaf=8, min_samples_split=4, n_estimators=50;, score=0.799 total time=   0.1s
# [CV 2/4] END max_depth=10, min_samples_leaf=8, min_samples_split=4, n_estimators=50;, score=0.766 total time=   0.1s
# [CV 3/4] END max_depth=10, min_samples_leaf=8, min_samples_split=4, n_estimators=50;, score=0.778 total time=   0.1s
# [CV 4/4] END max_depth=10, min_samples_leaf=8, min_samples_split=4, n_estimators=50;, score=0.725 total time=   0.1s
# [CV 1/4] END max_depth=10, min_samples_leaf=8, min_samples_split=4, n_estimators=100;, score=0.792 total time=   0.1s
# [CV 2/4] END max_depth=10, min_samples_leaf=8, min_samples_split=4, n_estimators=100;, score=0.773 total time=   0.1s
# [CV 3/4] END max_depth=10, min_samples_leaf=8, min_samples_split=4, n_estimators=100;, score=0.765 total time=   0.1s
# [CV 4/4] END max_depth=10, min_samples_leaf=8, min_samples_split=4, n_estimators=100;, score=0.739 total time=   0.1s
# [CV 1/4] END max_depth=10, min_samples_leaf=8, min_samples_split=4, n_estimators=250;, score=0.799 total time=   0.3s
# [CV 2/4] END max_depth=10, min_samples_leaf=8, min_samples_split=4, n_estimators=250;, score=0.773 total time=   0.3s
# [CV 3/4] END max_depth=10, min_samples_leaf=8, min_samples_split=4, n_estimators=250;, score=0.784 total time=   0.3s
# [CV 4/4] END max_depth=10, min_samples_leaf=8, min_samples_split=4, n_estimators=250;, score=0.732 total time=   0.3s
# [CV 1/4] END max_depth=10, min_samples_leaf=8, min_samples_split=8, n_estimators=50;, score=0.766 total time=   0.1s
# [CV 2/4] END max_depth=10, min_samples_leaf=8, min_samples_split=8, n_estimators=50;, score=0.786 total time=   0.1s
# [CV 3/4] END max_depth=10, min_samples_leaf=8, min_samples_split=8, n_estimators=50;, score=0.771 total time=   0.1s
# [CV 4/4] END max_depth=10, min_samples_leaf=8, min_samples_split=8, n_estimators=50;, score=0.752 total time=   0.1s
# [CV 1/4] END max_depth=10, min_samples_leaf=8, min_samples_split=8, n_estimators=100;, score=0.792 total time=   0.1s
# [CV 2/4] END max_depth=10, min_samples_leaf=8, min_samples_split=8, n_estimators=100;, score=0.753 total time=   0.1s
# [CV 3/4] END max_depth=10, min_samples_leaf=8, min_samples_split=8, n_estimators=100;, score=0.771 total time=   0.1s
# [CV 4/4] END max_depth=10, min_samples_leaf=8, min_samples_split=8, n_estimators=100;, score=0.719 total time=   0.1s
# [CV 1/4] END max_depth=10, min_samples_leaf=8, min_samples_split=8, n_estimators=250;, score=0.812 total time=   0.3s
# [CV 2/4] END max_depth=10, min_samples_leaf=8, min_samples_split=8, n_estimators=250;, score=0.773 total time=   0.3s
# [CV 3/4] END max_depth=10, min_samples_leaf=8, min_samples_split=8, n_estimators=250;, score=0.765 total time=   0.3s
# [CV 4/4] END max_depth=10, min_samples_leaf=8, min_samples_split=8, n_estimators=250;, score=0.732 total time=   0.4s
# GridSearchCV(cv=4, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [None, 5, 10],
#                          'min_samples_leaf': [2, 4, 8],
#                          'min_samples_split': [2, 4, 8],
#                          'n_estimators': [50, 100, 250]},
#              scoring='accuracy', verbose=3)

# %%
model_evaluator(X_train, y_train, gridsearch_model)
# Out:
# Accuracy score: 0.9186
# Precision score: 0.9323
# Recall score: 0.8287
# F1 score:0.8775
# Confusion matrix:
# [[385  13]
#  [ 37 179]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94       398
#            1       0.93      0.83      0.88       216
#
#     accuracy                           0.92       614
#    macro avg       0.92      0.90      0.91       614
# weighted avg       0.92      0.92      0.92       614

# %%
model_evaluator(X_test, y_test, gridsearch_model)
# Out:
# Accuracy score: 0.7857
# Precision score: 0.6939
# Recall score: 0.6538
# F1 score:0.6733
# Confusion matrix:
# [[87 15]
#  [18 34]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.85      0.84       102
#            1       0.69      0.65      0.67        52
#
#     accuracy                           0.79       154
#    macro avg       0.76      0.75      0.76       154
# weighted avg       0.78      0.79      0.78       154

# %%
np.round(pd.DataFrame(gridsearch_model.best_estimator_.feature_importances_,gridsearch_model.feature_names_in_)*100,3).sort_values(0, ascending=False)
# Out:
#                                0
# Glucose                   27.437
# BMI                       16.792
# Age                       15.490
# DiabetesPedigreeFunction  11.745
# Pregnancies                7.849
# BloodPressure              7.672
# Insulin                    6.525
# SkinThickness              6.490

# %%
main_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
gridsearch_model.best_estimator_.decision_path()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 gridsearch_model.best_estimator_.decision_path()
#
# TypeError: BaseForest.decision_path() missing 1 required positional argument: 'X'

# %% [markdown]
# # A MORE IDEAL WORKFLOW FOR PURER DATA SCIENCE

# %%
def splitter(num):
    train_df, test_df = train_test_split(main_df, test_size = num, random_state=4)

    X_train = train_df.drop(columns=['Outcome'])
    y_train = train_df['Outcome']
    X_test = test_df.drop(columns=['Outcome'])
    y_test = test_df['Outcome']

    return X_train, X_test, y_train, y_test

# %%
hyperparameter_dict = {'n_estimators': [50, 100],
                       'max_depth': [None, 5],
                       'min_samples_leaf': [2, 4]
                       }

def model_maker(X_train, X_test, y_train, y_test):
    gridsearch_model = GridSearchCV(estimator=RandomForestClassifier(),
                                param_grid=hyperparameter_dict,
                                scoring = 'accuracy',
                                cv=4)
    
    gridsearch_model.fit(X_train, y_train)
    print(gridsearch_model.best_params_)
    #print(gridsearch_model.best_params_)
    print("TRAINING DATA")
    model_evaluator(X_train, y_train, gridsearch_model)
    print("TESTING DATA")
    model_evaluator(X_test, y_test, gridsearch_model)

# %%
for i in [0.1, 0.15, 0.2, 0.25, 0.3]:
    print('*****************************')
    print(f'Data split of {i*100}%')
    sub_X_train, sub_X_test, sub_y_train, sub_y_test = splitter(i)
    model_maker(sub_X_train, sub_X_test, sub_y_train, sub_y_test)
# Out:
# *****************************
# Data split of 10.0%
# {'max_depth': 5, 'min_samples_leaf': 4, 'n_estimators': 100}
# TRAINING DATA
# Accuracy score: 0.8336
# Precision score: 0.836
# Recall score: 0.6529
# F1 score:0.7332
# Confusion matrix:
# [[418  31]
#  [ 84 158]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.93      0.88       449
#            1       0.84      0.65      0.73       242
#
#     accuracy                           0.83       691
#    macro avg       0.83      0.79      0.81       691
# weighted avg       0.83      0.83      0.83       691
#
# TESTING DATA
# Accuracy score: 0.8182
# Precision score: 0.7727
# Recall score: 0.6538
# F1 score:0.7083
# Confusion matrix:
# [[46  5]
#  [ 9 17]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.90      0.87        51
#            1       0.77      0.65      0.71        26
#
#     accuracy                           0.82        77
#    macro avg       0.80      0.78      0.79        77
# weighted avg       0.81      0.82      0.81        77
#
# *****************************
# Data split of 15.0%
# {'max_depth': None, 'min_samples_leaf': 4, 'n_estimators': 100}
# TRAINING DATA
# Accuracy score: 0.9187
# Precision score: 0.9187
# Recall score: 0.8421
# F1 score:0.8787
# Confusion matrix:
# [[407  17]
#  [ 36 192]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94       424
#            1       0.92      0.84      0.88       228
#
#     accuracy                           0.92       652
#    macro avg       0.92      0.90      0.91       652
# weighted avg       0.92      0.92      0.92       652
#
# TESTING DATA
# Accuracy score: 0.7586
# Precision score: 0.6667
# Recall score: 0.6
# F1 score:0.6316
# Confusion matrix:
# [[64 12]
#  [16 24]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.84      0.82        76
#            1       0.67      0.60      0.63        40
#
#     accuracy                           0.76       116
#    macro avg       0.73      0.72      0.73       116
# weighted avg       0.75      0.76      0.76       116
#
# *****************************
# Data split of 20.0%
# {'max_depth': 5, 'min_samples_leaf': 4, 'n_estimators': 50}
# TRAINING DATA
# Accuracy score: 0.8404
# Precision score: 0.8352
# Recall score: 0.6806
# F1 score:0.75
# Confusion matrix:
# [[369  29]
#  [ 69 147]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.93      0.88       398
#            1       0.84      0.68      0.75       216
#
#     accuracy                           0.84       614
#    macro avg       0.84      0.80      0.82       614
# weighted avg       0.84      0.84      0.84       614
#
# TESTING DATA
# Accuracy score: 0.7662
# Precision score: 0.6818
# Recall score: 0.5769
# F1 score:0.625
# Confusion matrix:
# [[88 14]
#  [22 30]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.86      0.83       102
#            1       0.68      0.58      0.62        52
#
#     accuracy                           0.77       154
#    macro avg       0.74      0.72      0.73       154
# weighted avg       0.76      0.77      0.76       154
#
# *****************************
# Data split of 25.0%
# {'max_depth': None, 'min_samples_leaf': 2, 'n_estimators': 50}
# TRAINING DATA
# Accuracy score: 0.9792
# Precision score: 0.9847
# Recall score: 0.9554
# F1 score:0.9698
# Confusion matrix:
# [[371   3]
#  [  9 193]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       374
#            1       0.98      0.96      0.97       202
#
#     accuracy                           0.98       576
#    macro avg       0.98      0.97      0.98       576
# weighted avg       0.98      0.98      0.98       576
#
# TESTING DATA
# Accuracy score: 0.7917
# Precision score: 0.6912
# Recall score: 0.7121
# F1 score:0.7015
# Confusion matrix:
# [[105  21]
#  [ 19  47]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.83      0.84       126
#            1       0.69      0.71      0.70        66
#
#     accuracy                           0.79       192
#    macro avg       0.77      0.77      0.77       192
# weighted avg       0.79      0.79      0.79       192
#
# *****************************
# Data split of 30.0%
# {'max_depth': None, 'min_samples_leaf': 4, 'n_estimators': 50}
# TRAINING DATA
# Accuracy score: 0.9236
# Precision score: 0.9302
# Recall score: 0.8466
# F1 score:0.8864
# Confusion matrix:
# [[336  12]
#  [ 29 160]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.94       348
#            1       0.93      0.85      0.89       189
#
#     accuracy                           0.92       537
#    macro avg       0.93      0.91      0.91       537
# weighted avg       0.92      0.92      0.92       537
#
# TESTING DATA
# Accuracy score: 0.7792
# Precision score: 0.6707
# Recall score: 0.6962
# F1 score:0.6832
# Confusion matrix:
# [[125  27]
#  [ 24  55]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.82      0.83       152
#            1       0.67      0.70      0.68        79
#
#     accuracy                           0.78       231
#    macro avg       0.75      0.76      0.76       231
# weighted avg       0.78      0.78      0.78       231

# %%
gridsearch_model.best_params_
# Out:
# {'max_depth': None,
#  'min_samples_leaf': 4,
#  'min_samples_split': 8,
#  'n_estimators': 250}

# %%
plt.figure(figsize=(50,50))
plot_tree(gridsearch_model.best_estimator_.estimators_[2], feature_names=X_train.columns)
plt.show()
plt.savefig('fig1.png');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.figure(figsize=(50,50))
#       2 plot_tree(gridsearch_model.best_estimator_.estimators_[2], feature_names=X_train.columns)
#       3 plt.show()
#
# NameError: name 'plt' is not defined
